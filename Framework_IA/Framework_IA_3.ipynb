# %% [markdown]
# ## Seção 03 - CNN
# # Aluno: Bruno Moreira Ribas

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten,Dropout
from tensorflow.keras.models import Model

# %% [markdown]
# # Classificação - Fashion MNIST

# %%
# Carga dos dados
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# normalizar os dados
x_train, x_test = x_train / 255.0, x_test / 255.0
print("x_train.shape: ", x_train.shape)
print("x_test.shape: ", x_test.shape)
# Adicionar uma dimensão:
# N x H x W -> N x H x W x C
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train.shape: ", x_train.shape)
print("x_test.shape: ", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# x_train.shape:  (60000, 28, 28)
# x_test.shape:  (10000, 28, 28)
# x_train.shape:  (60000, 28, 28, 1)
# x_test.shape:  (10000, 28, 28, 1)

# %%
# número de classes
K = len(set(y_train))
# Camadas
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), strides=2, activation="relu")(i)
x = Conv2D(64, (3, 3), strides=2, activation="relu")(x)
x = Conv2D(128, (3, 3), strides=2, activation="relu")(x)
x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(512, activation="relu")(x)
x = Dropout(0.2)(x)
x = Dense(K, activation="softmax")(x)
# Model ( lista entrada, lista saída)
model = Model(i, x)



model.compile(optimizer="adam",
loss="sparse_categorical_crossentropy",
metrics=["accuracy"])
r = model.fit(x_train, y_train, validation_data=(x_test, y_test),
epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.5194 - accuracy: 0.8077 - val_loss: 0.3887 - val_accuracy: 0.8519
# Epoch 2/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.3617 - accuracy: 0.8639 - val_loss: 0.3584 - val_accuracy: 0.8661
# Epoch 3/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.3108 - accuracy: 0.8824 - val_loss: 0.3149 - val_accuracy: 0.8860
# Epoch 4/15
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.2787 - accuracy: 0.8955 - val_loss: 0.3164 - val_accuracy: 0.8838
# Epoch 5/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.2541 - accuracy: 0.9050 - val_loss: 0.3026 - val_accuracy: 0.8887
# Epoch 6/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.2297 - accuracy: 0.9124 - val_loss: 0.2900 - val_accuracy: 0.8974
# Epoch 7/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.2126 - accuracy: 0.9190 - val_loss: 0.2996 - val_accuracy: 0.8952
# Epoch 8/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.1936 - accuracy: 0.9258 - val_loss: 0.3164 - val_accuracy: 0.8934
# Epoch 9/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.1822 - accuracy: 0.9302 - val_loss: 0.2963 - val_accuracy: 0.9018
# Epoch 10/15
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.1697 - accuracy: 0.9360 - val_loss: 0.3140 - val_accuracy: 0.9009
# Epoch 11/15
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1577 - accuracy: 0.9396 - val_loss: 0.3137 - val_accuracy: 0.8990
# Epoch 12/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.1479 - accuracy: 0.9432 - val_loss: 0.3414 - val_accuracy: 0.8995
# Epoch 13/15
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1398 - accuracy: 0.9464 - val_loss: 0.3446 - val_accuracy: 0.8976
# Epoch 14/15
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1313 - accuracy: 0.9509 - val_loss: 0.3476 - val_accuracy: 0.8979
# Epoch 15/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.1271 - accuracy: 0.9516 - val_loss: 0.3851 - val_accuracy: 0.8992

# %%
# Plotar a função de perda
plt.plot(r.history["loss"], label="loss")
plt.plot(r.history["val_loss"], label="val_loss")
plt.legend()
# Plotar acurácia
plt.plot(r.history["accuracy"], label="acc")
plt.plot(r.history["val_accuracy"], label="val_acc")
plt.legend()

# %%
# Efetuar predições
y_pred = model.predict(x_test).argmax(axis=1)
# Mostrar a matriz de confusão
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(conf_mat=cm, figsize=(7, 7), show_normed=True)
# Out:
# 313/313 [==============================] - 3s 8ms/step
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %%
labels = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
misclassified = np.where(y_pred != y_test)[0]
i = np.random.choice(misclassified)
plt.imshow(x_test[i].reshape(28, 28), cmap="gray")
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]],
labels[y_pred[i]]))
# Out:
# Text(0.5, 1.0, 'True label: Coat Predicted: Dress')

# %% [markdown]
# # CIFAR 10

# %%
cifar10 = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# normalizar os dados
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print("x_train.shape: ", x_train.shape)
print("y_train.shape: ", y_train.shape)
print("x_test.shape: ", x_test.shape)
print("y_test.shape: ", y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# x_train.shape:  (50000, 32, 32, 3)
# y_train.shape:  (50000,)
# x_test.shape:  (10000, 32, 32, 3)
# y_test.shape:  (10000,)

# %%
# número de classes
K = len(set(y_train))
# Camadas
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), strides=2, activation="relu")(i)
x = Conv2D(64, (3, 3), strides=2, activation="relu")(x)
x = Conv2D(128, (3, 3), strides=2, activation="relu")(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.2)(x)
x = Dense(K, activation="softmax")(x)
# Model ( lista entrada, lista saída)
model = Model(i, x)

# %%
model.compile(optimizer="adam",
loss="sparse_categorical_crossentropy",
metrics=["accuracy"])
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 64s 39ms/step - loss: 1.5547 - accuracy: 0.4313 - val_loss: 1.2678 - val_accuracy: 0.5444
# Epoch 2/15
# 1563/1563 [==============================] - 55s 35ms/step - loss: 1.2784 - accuracy: 0.5436 - val_loss: 1.1522 - val_accuracy: 0.5912
# Epoch 3/15
# 1563/1563 [==============================] - 61s 39ms/step - loss: 1.1506 - accuracy: 0.5891 - val_loss: 1.0453 - val_accuracy: 0.6303
# Epoch 4/15
# 1563/1563 [==============================] - 59s 38ms/step - loss: 1.0637 - accuracy: 0.6203 - val_loss: 0.9998 - val_accuracy: 0.6384
# Epoch 5/15
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.9854 - accuracy: 0.6506 - val_loss: 0.9554 - val_accuracy: 0.6582
# Epoch 6/15
# 1563/1563 [==============================] - 57s 36ms/step - loss: 0.9268 - accuracy: 0.6728 - val_loss: 0.9039 - val_accuracy: 0.6852
# Epoch 7/15
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.8755 - accuracy: 0.6881 - val_loss: 0.9028 - val_accuracy: 0.6887
# Epoch 8/15
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.8291 - accuracy: 0.7059 - val_loss: 0.8766 - val_accuracy: 0.6953
# Epoch 9/15
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.7913 - accuracy: 0.7203 - val_loss: 0.8571 - val_accuracy: 0.7024
# Epoch 10/15
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.7558 - accuracy: 0.7326 - val_loss: 0.8322 - val_accuracy: 0.7124
# Epoch 11/15
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.7274 - accuracy: 0.7415 - val_loss: 0.8454 - val_accuracy: 0.7104
# Epoch 12/15
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.6977 - accuracy: 0.7503 - val_loss: 0.8553 - val_accuracy: 0.7055
# Epoch 13/15
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.6766 - accuracy: 0.7591 - val_loss: 0.8106 - val_accuracy: 0.7235
# Epoch 14/15
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.6513 - accuracy: 0.7656 - val_loss: 0.8129 - val_accuracy: 0.7227
# Epoch 15/15
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.6355 - accuracy: 0.7748 - val_loss: 0.8127 - val_accuracy: 0.7199

# %%
# Plotar a função de perda
plt.plot(r.history["loss"], label="loss")
plt.plot(r.history["val_loss"], label="val_loss")
plt.legend()
# Plotar acurácia
plt.plot(r.history["accuracy"], label="acc")
plt.plot(r.history["val_accuracy"], label="val_acc")
plt.legend()

# %%
# Efetuar predições
y_pred = model.predict(x_test).argmax(axis=1)
# Mostrar a matriz de confusão
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(conf_mat=cm, figsize=(7, 7), show_normed=True)
# Out:
# 313/313 [==============================] - 2s 8ms/step
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %%
# Mostrar algumas classificaç!oes erradas
labels = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
misclassified = np.where(y_pred != y_test)[0]
i = np.random.choice(misclassified)
plt.imshow(x_test[i], cmap="gray")
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[y_pred[i]]))
# Out:
# Text(0.5, 1.0, 'True label: cat Predicted: frog')
